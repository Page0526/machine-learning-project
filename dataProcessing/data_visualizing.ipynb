# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
cd = os.getcwd()
parent_dir = os.path.dirname(cd)
data_path = os.path.join(parent_dir, 'data')
print(data_path)
# Out:
# d:\VSC\machine-learning-project\data

# %%
data = pd.read_csv(os.path.join(data_path, 'final_data.csv'), index_col=None)

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data
# Out:
#                                   Release Group       Domestic Distributor  \
# 0               Godzilla x Kong: The New Empire               Warner Bros.
# 1                               Kung Fu Panda 4         Universal Pictures
# 2                   Ghostbusters: Frozen Empire    Sony Pictures Releasing
# 3                          Bob Marley: One Love         Paramount Pictures
# 4                                 The Beekeeper  Metro-Goldwyn-Mayer (MGM)
# ...                                         ...                        ...
# 1561                                     Shower    Sony Pictures Releasing
# 1562                               Left Luggage    Castle Hill Productions
# 1563                                     Hamlet                    Miramax
# 1564  The Broken Hearts Club: A Romantic Comedy     Sony Pictures Classics
# 1565                          Cecil B. Demented      Artisan Entertainment
#
# ...

# %%
# millions = 1000000000
# if data['Worldwide'].any() > 1000:
#     data['Worldwide'] = data['Worldwide']/millions
# data['Domestic'] = data['Domestic'] / millions
# data['Foreign'] = data['Foreign'] / millions

# %% [markdown]
# ## Top 10 highest-revenue movies all of year (from 2000-2024)

# %%
top_worldwide_revenue = data.sort_values(by=['Worldwide'], ascending=False)[0:10]
top_worldwide_revenue
# Out:
#                                     Release Group  \
# 194                      Avatar: The Way of Water
# 501                        Avengers: Infinity War
# 319                       Spider-Man: No Way Home
# 195                             Top Gun: Maverick
# 57                                         Barbie
# 58                    The Super Mario Bros. Movie
# 502                                 Black Panther
# 923  Harry Potter and the Deathly Hallows: Part 2
# 889                          Beauty and the Beast
# 797                          Beauty and the Beast
#
#                     Domestic Distributor Earliest Release date  \
# 194                 20th Century Studios     December 14, 2022
# 501  Walt Disney Studios Motion Pictures        April 25, 2018
# 319              Sony Pictures Releasing     December 15, 2021
# 195                   Paramount Pictures          May 20, 2022
# 57                          Warner Bros.         July 19, 2023
# ...

# %%
data.loc[data['Worldwide'] >= 1].shape
# Out:
# (1566, 14)

# %%
data.loc[data['Worldwide'] < 1].shape
# Out:
# (0, 14)

# %%
plt.figure(figsize=(12, 6))
plt.plot(top_worldwide_revenue['Release Group'], top_worldwide_revenue['Worldwide'])
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.xlabel('Movies')
plt.ylabel('Worldwide Revenue (100 Millions dollar)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## MPAA counts
# R: restricted
#
# G: general audiences
#
# PG-13: parents strongly cautioned
#
# PG: parental guidance suggested

# %%
data['MPAA'].unique()
# Out:
# array(['PG-13', 'PG', 'R', 'G', 'Not Rated'], dtype=object)

# %%
plt.bar(data['MPAA'].unique(),data['MPAA'].value_counts(), width=0.4)
# Out:
# <BarContainer object of 5 artists>

# %%
data['Genres'].value_counts()
# Out:
# Genres
# ['Comedy', 'Drama', 'Romance']                           60
# ['Comedy', 'Drama']                                      56
# ['Drama', 'Romance']                                     54
# ['Drama']                                                50
# ['Comedy', 'Romance']                                    44
#                                                          ..
# ['Drama', 'History', 'Romance', 'War']                    1
# ['Biography', 'Comedy', 'Drama', 'Family', 'History']     1
# ['Adventure', 'Documentary', 'Sport']                     1
# ['Adventure', 'Drama', 'Romance', 'Thriller']             1
# ['Adventure', 'Drama', 'History', 'Romance']              1
# Name: count, Length: 509, dtype: int64

# %%
data
# Out:
#                                   Release Group       Domestic Distributor  \
# 0               Godzilla x Kong: The New Empire               Warner Bros.
# 1                               Kung Fu Panda 4         Universal Pictures
# 2                   Ghostbusters: Frozen Empire    Sony Pictures Releasing
# 3                          Bob Marley: One Love         Paramount Pictures
# 4                                 The Beekeeper  Metro-Goldwyn-Mayer (MGM)
# ...                                         ...                        ...
# 1561                                     Shower    Sony Pictures Releasing
# 1562                               Left Luggage    Castle Hill Productions
# 1563                                     Hamlet                    Miramax
# 1564  The Broken Hearts Club: A Romantic Comedy     Sony Pictures Classics
# 1565                          Cecil B. Demented      Artisan Entertainment
#
# ...

# %%
plt.figure(figsize=(12, 6))
plt.xlabel('Worldwide')
plt.ylabel('Density')
sns.kdeplot(data['Worldwide'], shade=True)
# Out:
# C:\Users\Phuong Trang\AppData\Local\Temp\ipykernel_25796\1445863833.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['Worldwide'], shade=True)
# <Axes: xlabel='Worldwide', ylabel='Density'>

# %% [markdown]
# Hmm... Trung bình doanh thu toàn cầu của ngành điện ảnh tại Mỹ (datasource: box office) rơi vào khoảng 10 triệu đô

# %%
data.loc[(data['Worldwide'] > 0) & (data['Worldwide'] < 1)].value_counts()
# Out:
# Release Group               Domestic Distributor       Earliest Release date  Earliest Release region  MPAA   Running Time  Genres                                                             Overview                                                                                                                                                                                                                                               Actors                                                                Film makers                                                                                                                                                                                                                                                                                                                      Worldwide  Domestic  Foreign   Year
# ...

# %%
data['Worldwide'].mean()
# Out:
# 1.011976640983397

# %%
data['Foreign'].mean()
# Out:
# 0.6707696044061302

# %%
data['Domestic'].mean()
# Out:
# 0.34120285491698593

# %%
data['Domestic'].mean() + data['Foreign'].mean()
# Out:
# 1.011972459323116

# %%
type(data['Genres'])
# Out:
# pandas.core.series.Series

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Release Group            1566 non-null   object
#  1   Domestic Distributor     1566 non-null   object
#  2   Earliest Release date    1566 non-null   object
#  3   Earliest Release region  1566 non-null   object
#  4   MPAA                     1566 non-null   object
#  5   Running Time             1566 non-null   object
#  6   Genres                   1566 non-null   object
#  7   Overview                 1566 non-null   object
#  8   Actors                   1566 non-null   object
#  9   Film makers              1566 non-null   object
#  10  Worldwide                1566 non-null   float64
#  11  Domestic                 1566 non-null   float64
#  12  Foreign                  1566 non-null   float64
#  13  Year                     1566 non-null   int64
# ...
